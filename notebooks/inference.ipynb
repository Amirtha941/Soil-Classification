# %%
"""

Author: Annam.ai IIT Ropar
Team Name: AgroMinds AI
Team Members: Tharun Babu C , Amirtha K
Leaderboard Rank: 41

"""

# This is the notebook used for making the inferences using the model trained.
# Out:
# '\n\nAuthor: Annam.ai IIT Ropar\nTeam Name: AgroMinds AI\nTeam Members: Tharun Babu C , Amirtha K\nLeaderboard Rank: 41\n\n'
