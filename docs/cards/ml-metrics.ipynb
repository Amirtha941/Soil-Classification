# %%
{
  "_comment": "This file contains evaluation metrics for the soil classification project",
  "Team members": "Amirtha K And Tharun Babu C",
  "Kaggle Username": "amirtha1409 and tharunbabu20",
  "Team Name": "AgroMinds AI",
  "Best Epoch": 6,
  "Min F1 Scores per Epoch": {
    "1": 0.8788,
    "2": 0.9355,
    "3": 0.9508,
    "4": 0.9836,
    "5": 0.9474,
    "6": 0.9855,
    "7": 0.9831,
    "8": 0.9836,
    "9": 0.9831,
    "10": 0.9524
  },
  "Best F1 Scores": {
    "alluvial soil": 0.9937,
    "red soil": 1.0,
    "black soil": 1.0,
    "clay soil": 0.9855
  }
}
# Out:
# {'_comment': 'This file contains evaluation metrics for the soil classification project',
#  'Team members': 'Amirtha K And Tharun Babu C',
#  'Kaggle Username': 'amirtha1409 and tharunbabu20',
#  'Team Name': 'AgroMinds AI',
#  'Best Epoch': 6,
#  'Min F1 Scores per Epoch': {'1': 0.8788,
#   '2': 0.9355,
#   '3': 0.9508,
#   '4': 0.9836,
#   '5': 0.9474,
#   '6': 0.9855,
#   '7': 0.9831,
#   '8': 0.9836,
#   '9': 0.9831,
#   '10': 0.9524},
#  'Best F1 Scores': {'alluvial soil': 0.9937,
#   'red soil': 1.0,
#   'black soil': 1.0,
#   'clay soil': 0.9855}}
